# %% [markdown]
# # How to Handle missing record using Sklearn:-

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset/weather_data.txt")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df1=df.set_index('day')
df1
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df1.isnull().sum()
# Out:
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='mean')
#strategy = "mean","median","most frequent" (it work on both numeric or 
#categorical data),"constant"

# %%
df1.iloc[:,0:2]=imputer.fit_transform(df1.iloc[:,0:2])
df1
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          33.2        9.0   Sunny
# 1/5/2017          28.0        8.4    Snow
# 1/6/2017          33.2        7.0     NaN
# 1/7/2017          32.0        8.4    Rain
# 1/8/2017          33.2        8.4   Sunny
# 1/9/2017          33.2        8.4     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df2=df.set_index('day')
df2
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='median')

# %%
df2.iloc[:,0:2]=imputer.fit_transform(df2.iloc[:,0:2])
df2
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        8.0    Snow
# 1/6/2017          32.0        7.0     NaN
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          32.0        8.0   Sunny
# 1/9/2017          32.0        8.0     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df3=df.set_index('day')
df3
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
df3.iloc[:,:]=imputer.fit_transform(df3.iloc[:,:])
df3
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        6.0    Snow
# 1/6/2017          32.0        7.0   Sunny
# 1/7/2017          32.0        6.0    Rain
# 1/8/2017          32.0        6.0   Sunny
# 1/9/2017          32.0        6.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df4=df.set_index('day')
df4
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='constant',fill_value=4)

# %%
df4.iloc[:,:]=imputer.fit_transform(df4.iloc[:,:])
df4
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           4.0        9.0   Sunny
# 1/5/2017          28.0        4.0    Snow
# 1/6/2017           4.0        7.0       4
# 1/7/2017          32.0        4.0    Rain
# 1/8/2017           4.0        4.0   Sunny
# 1/9/2017           4.0        4.0       4
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny
